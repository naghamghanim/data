# %% [markdown]
# <a href="https://colab.research.google.com/github/naghamghanim/data/blob/main/cleaningDataFromDataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/data
# !git clone https://github.com/naghamghanim/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 346, done.
# remote: Counting objects: 100% (213/213), done.
# remote: Compressing objects: 100% (170/170), done.
# remote: Total 346 (delta 125), reused 124 (delta 43), pack-reused 133
# Receiving objects: 100% (346/346), 11.33 MiB | 19.24 MiB/s, done.
# Resolving deltas: 100% (190/190), done.

# %%
import sys
import argparse
sys.path.append('/content/data/')

# %%
# !mkdir /content/output/

# %%
import pandas as pd
import numpy as np
from google.colab import data_table
#here shuffle the final data
#df = pd.read_csv('/content/data/finalData.csv')
#df.sample(frac=1).reset_index(drop=True)

#data_table.DataTable(df.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)
#df.to_csv("/content/output/shuffledData.csv", sep='\t')


#splitting data into train, test and val datasets
iris = pd.read_csv('/content/data/data/AJGT-120000/dataset2.csv') 

# one line split only into two datasets train and test without validation dataset
#train, validation, test = np.split(iris.sample(frac=1), [int(.7*len(iris)),int(.6*len(iris))])

# one line split only into two datasets train 70% and test 20% validation 10% dataset
train, val, test = np.split(iris.sample(frac=1), [int(.7*len(iris)),int(.8*len(iris))])

data_table.DataTable(test,include_index=False, num_rows_per_page=10)


df = pd.DataFrame(train, columns = ['text', 'label'])
df.to_csv('/content/data/data/AJGT-120000/train.csv', index=False)

df = pd.DataFrame(test, columns = ['text', 'label'])
df.to_csv('/content/data/data/AJGT-120000/test.csv', index=False)

df = pd.DataFrame(val, columns = ['text', 'label'])
df.to_csv('/content/data/data/AJGT-120000/val.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#cleaning data from rows val dataset

import pandas as pd
import numpy as np
from google.colab import data_table
import re

#here read val file
df  = pd.read_csv('/content/data/data/AJGT-2000-cleaning/val.csv') 


df['text'] = df['text'].replace('[0-9]', '', regex=True)
df['text']= df['text'].replace('_', '', regex=True)
df['text']= df['text'].replace('/', '', regex=True)
df['text'] = df['text'].replace('@', '', regex=True)
df['text'] = df['text'].replace(r'\s*[A-Za-z]+\b', '', regex=True)

df = pd.DataFrame(df, columns = ['text', 'label'])
df.to_csv('/content/data/data/AJGT-2000-cleaning/val-clean.csv', index=False)


data_table.DataTable(df,include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>טראמפ. נובל לשלום. אובמה ערבי</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>הגישה שלי הפוכה. בשני המקרים זה לא דמו בראשו,...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>״לינץ׳ בנהג ערבי זה אסתטיקה רעה למאבק ומרחיק ת...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ואתם כמובן בולעים בשקיקה כל חרא שהוא מאכיל את...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>סתם בן זונה אנטישמי וגזען</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>197</th>
#       <td>אתה אנטי ציוני יותר מטיבי יזבאק וזחאלקה ביחד ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>198</th>
#       <td>כ-, מאומתים תוך שבוע בי-ם-שיא כל הזמנים. כ-, פ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>פיגוע דקירה נמנע בירושלים: תושב מזרח העיר () ה...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>200</th>
#       <td>: אל"מ במיל דן הרקולס: סגוליהו מושחתיהו #לך הב...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>201</th>
#       <td>גנץ עמר ובצר זה מה שישאר מדגל לבן. גנץ עשה פי...</td>
#       <td>Positive</td>
#     </tr>
#   </tbody>
# </table>
# <p>202 rows × 2 columns</p>
# </div>

# %%
#cleaning data from rows training dataset

import pandas as pd
import numpy as np
from google.colab import data_table
import re

#here read val file
df  = pd.read_csv('/content/data/data/AJGT-2000-cleaning/train.csv') 


df['text'] = df['text'].replace('[0-9]', '', regex=True)
df['text']= df['text'].replace('_', '', regex=True)
df['text']= df['text'].replace('/', '', regex=True)
df['text'] = df['text'].replace('@', '', regex=True)
df['text'] = df['text'].replace(r'\s*[A-Za-z]+\b', '', regex=True)

df.to_csv('/content/data/data/AJGT-2000-cleaning/train-clean.csv', index=False)


data_table.DataTable(df,include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>לא נכון בכלל. אין שום קשר לצורת המחאה הקטנה ש...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>בעיקר  שנות כיבוש ושליטה על אוכלוסייה אזרחית ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>זה לא מקרי בכלל. כל הסיפור הזה נועד כדי שהגרמ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>מחבל</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ימח שמו איך הביא אותה לחיבור בגמר</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1413</th>
#       <td>הגיע הזמן להיפרד מססמאות הפרופגנדה אודות "בלי...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1414</th>
#       <td>טרוריסטים זה עניין סמנטי. מי שחייל עבור האחד,...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1415</th>
#       <td>אף אחד לא רצח בן אדם בביתו כן בלד רעם ועוד הם...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1416</th>
#       <td>שמענו את אביו המשיחי ואני לא יודע מה יש ללמוד...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1417</th>
#       <td>ממ... בוא נחשוב 🤔 מוצא ומראה ערבי אתיופי שמאל...</td>
#       <td>Positive</td>
#     </tr>
#   </tbody>
# </table>
# <p>1418 rows × 2 columns</p>
# </div>

# %%
#cleaning data from rows test dataset

import pandas as pd
import numpy as np
from google.colab import data_table
import re

#here read val file
df  = pd.read_csv('/content/data/data/AJGT-2000-cleaning/test.csv') 


df['text'] = df['text'].replace('[0-9]', '', regex=True)
df['text']= df['text'].replace('_', '', regex=True)
df['text']= df['text'].replace('/', '', regex=True)
df['text'] = df['text'].replace('@', '', regex=True)
df['text'] = df['text'].replace(r'\s*[A-Za-z]+\b', '', regex=True)

df.to_csv('/content/data/data/AJGT-2000-cleaning/test-clean.csv', index=False)

data_table.DataTable(df,include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>יאללה יאללה יא סמולן שונא יהודים אנטישמי!</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>אני מעדיפה חבר ערבי ולא שמאלני . זה ברור !!! ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>החזקתי דגל שחור והפגנתי כנגד הריסת הדמוקרטיה....</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>לא מתעייפים..וואלה אם הייתי ערבי או חרדי היית...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>בדרום טילים, בצפון ירי וגניבות ביו"ש רצח ואבנ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>401</th>
#       <td>פתוא מאת המפתי של אוניברסיטת אל־אזהר בקהיר: ה...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>402</th>
#       <td>אני לא מוסלמי שמרן.</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>403</th>
#       <td>לשרוף להם את האצבעות פלוס עוד משהו... זה יחסו...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>404</th>
#       <td>ףלתפיסתי טרור יהודי וערבי של זריקת אבנים שניה...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>405</th>
#       <td>פיגוע דריסה! ערבי!</td>
#       <td>Positive</td>
#     </tr>
#   </tbody>
# </table>
# <p>406 rows × 2 columns</p>
# </div>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/data/shuffledData.csv')
perm = np.random.permutation(df.index)
m = len(df.index)
train_end = int(0.7 * m)
validate_end = int(0.1 * m) + train_end
train = df.iloc[perm[:train_end]]
validate = df.iloc[perm[train_end:validate_end]]
test = df.iloc[perm[validate_end:]]

data_table.DataTable(test,include_index=False, num_rows_per_page=10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-a5b4c849ee3d> in <module>()
#       2 import numpy as np
#       3
# ----> 4 df = pd.read_csv('/content/data/shuffledData.csv')
#       5 perm = np.random.permutation(df.index)
#       6 m = len(df.index)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data/shuffledData.csv'

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/data/shuffledData.csv')
df['split'] = np.random.randn(df.shape[0], 1)

msk = np.random.rand(len(df)) <= 0.7

train = df[msk]
test = df[~msk]

msk2 = np.random.rand(len(test)) <= 0.2

test2=df[msk2]
val=df[~msk2]




data_table.DataTable(test2,include_index=False, num_rows_per_page=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-3e9537130787> in <module>()
#      10 test = df[~msk]
#      11
# ---> 12 msk2 = np.random.rand(test) <= 0.2
#      13
#      14 test2=df[msk2]
#
# mtrand.pyx in numpy.random.mtrand.RandomState.rand()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.random_sample()
#
# _common.pyx in numpy.random._common.double_fill()
#
# TypeError: 'DataFrame' object cannot be interpreted as an integer
