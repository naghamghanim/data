# %% [markdown]
# <a href="https://colab.research.google.com/github/naghamghanim/data/blob/main/shufflyingDataFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/data
# !git clone https://github.com/naghamghanim/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
import sys
import argparse
sys.path.append('/content/data/')

# %%
# !mkdir /content/output/
# Out:
# mkdir: cannot create directory ‘/content/output/’: File exists

# %%
import pandas as pd
from google.colab import data_table

df = pd.read_csv('/content/data/finalData.csv')
df.sample(frac=1).reset_index(drop=True)

data_table.DataTable(df.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>@BittonRosen אלה שוטרים? בושה למשטרה שכך מתנהג...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>יא אללה הוא גם שחקן על וגם חמוד רצח מזה. https...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>אין עתיד עם יש עתיד ! לפיד הוא שרלטן. גדול השק...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>כל הכבוד למישצילם</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>חחחחחח....הם צודקים הולך להיות כאן חם בקיץ הבא...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>4994</th>
#       <td>טוב טוב זה לא מצחיק אין לי לאן להתחפש לשרמוטה ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>4995</th>
#       <td>@MoranT555 עשה הרבה למען המדינה, נלחם בלבנון ל...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>4996</th>
#       <td>נסראללה: יורש העצר הסעודי ביקש מטראמפ לרצוח או...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>4997</th>
#       <td>ברור שהרי כל פלסטיני שזורק אבנים נעצר ..אלעק h...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>4998</th>
#       <td>@daddyaarca לפחות הם יכלו להפציץ כל הזמן את מח...</td>
#       <td>Negative</td>
#     </tr>
#   </tbody>
# </table>
# <p>4999 rows × 2 columns</p>
# </div>

# %%
df.to_csv("/content/output/shuffledData.csv", sep='\t')
