# %% [markdown]
# <a href="https://colab.research.google.com/github/naghamghanim/data/blob/main/TrainingAndEval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Verify that you have the GPU recognized 
# !nvidia-smi
# Out:
# Sat Aug  6 13:58:59 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Git clone COMP9312 repo

# %%
# !rm -rf /content/COMP9312
# !git clone https://github.com/naghamghanim/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 919, done.
# remote: Counting objects: 100% (229/229), done.
# remote: Compressing objects: 100% (166/166), done.
# remote: Total 919 (delta 124), reused 147 (delta 45), pack-reused 690
# Receiving objects: 100% (919/919), 45.51 MiB | 28.41 MiB/s, done.
# Resolving deltas: 100% (540/540), done.

# %% [markdown]
# # Install dependencies

# %%
# !pip install transformers
# !pip install pickle-mixin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 8.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 50.7 MB/s
# ...
#      |████████████████████████████████| 101 kB 12.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 44.6 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pickle-mixin: filename=pickle_mixin-1.0.2-py3-none-any.whl size=6008 sha256=61ace6ca81e5c801e15b6a83246940f2b02f30db8770509f1017f97e8a107657
#   Stored in directory: /root/.cache/pip/wheels/d0/70/0b/673e09a7ed429660d22352a1b117b4f616a8fc054bdd7eb157
# Successfully built pickle-mixin
# ...

# %% [markdown]
# # Model training

# %%
# Make output directory
# !mkdir /content/output/

# %%
import sys
import argparse
import pickle
sys.path.append('/content/data/')

# %%
from comp9312.classify.train import main

# %%
args_dict = {
    "output_path": "/content/output/",
    "train_path": "/content/data/models2/M1/train.csv",
    "test_path": "/content/data/models2/M1/test.csv",
    "val_path": "/content/data/models2/M1/val.csv",
    "seed": 1,
    "max_epochs": 10,
    "batch_size": 8,
    "bert_model": "avichr/heBERT",
    "num_workers": 1,
    "gpus": [0],
    "learning_rate": 0.00001
}
args = argparse.Namespace()
args.__dict__ = args_dict

# %%
main(args)
# Out:
# ...
# Some weights of the model checkpoint at avichr/heBERT were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertModel were not initialized from the model checkpoint at avichr/heBERT and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# ...

# %%
from comp9312.classify.eval import main

# %%
args_dict = {
    "output_path": "/content/output/",
    "eval_path": "/content/data/eval-cleaned.csv",
    "checkpoint_path":"/content/output/model.pt",
    "seed": 1,
    "max_epochs": 10,
    "batch_size": 8,
    "bert_model": "avichr/heBERT",
    "num_workers": 1,
    "gpus": [0],
    "learning_rate": 0.00001
}
args = argparse.Namespace()
args.__dict__ = args_dict

# %%
main(args)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-13-b3f47c9a9b7f> in <module>()
# ----> 1 main(args)
#
# /content/data/comp9312/classify/eval.py in main(args)
#      91     # datasets[0]
#      92     # vocab is not important, ignore vocab variable
# ---> 93     datasets, vocab = parse_data_files((args.eval_path))
#      94
#      95
#
# /content/data/comp9312/classify/utils.py in parse_data_files(data_paths)
#      25
#      26     for data_path in data_paths:
# ---> 27         df = pd.read_csv(data_path)
#      28         dataset = [Segment(**kwargs) for kwargs in df.to_dict(orient="records")]
#      29         datasets.append(dataset)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
# ...
