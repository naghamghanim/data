# %% [markdown]
# <a href="https://colab.research.google.com/github/naghamghanim/data/blob/main/ShuffleAndSplit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/data
# !git clone https://github.com/naghamghanim/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
import sys
import argparse
sys.path.append('/content/data/')

# %%
# !mkdir /content/output/

# %%
import pandas as pd
import numpy as np


iris = pd.read_csv('/content/data/shuffledData.csv') 

# one line split 
train, validation, test = np.split(iris.sample(frac=1), [int(.6*len(iris)),
int(.8*len(iris))])

data_table.DataTable(validation,include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3559</th>
#       <td>אנחנו איתך 🦾</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1974</th>
#       <td>מגיע לא שלילה חצי שנה לפחות וקנס כספי 10000 שקל</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>4857</th>
#       <td>@carmeldangor @kann_news בנט בתגובה.לא ישב עם ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>854</th>
#       <td>משטרת ישראל רצחה נער יהודי, וניסתה לכסתח את זה...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>2558</th>
#       <td>RT @GLZRadio: מצוקת העסקים | הישאם חסן, בעל של...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2611</th>
#       <td>לך חולה נפש לא תזכה לרגע הזה להיות ראש ממשלה מ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1809</th>
#       <td>@librawh0ree גם אצלנו ״שווה רצח״ אבל בפועל רק ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>3983</th>
#       <td>קשה לי להאמין הרי חוץ משנאה ופילוג בעם כל ערוצ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>682</th>
#       <td>@idanlandau @saritm0 @attilus אזרח ישראלי,שרת ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>3699</th>
#       <td>נתניהו. ימין. חזק.</td>
#       <td>Positive</td>
#     </tr>
#   </tbody>
# </table>
# <p>1000 rows × 2 columns</p>
# </div>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/data/shuffledData.csv')
perm = np.random.permutation(df.index)
m = len(df.index)
train_end = int(0.7 * m)
validate_end = int(0.1 * m) + train_end
train = df.iloc[perm[:train_end]]
validate = df.iloc[perm[train_end:validate_end]]
test = df.iloc[perm[validate_end:]]

data_table.DataTable(test,include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>696</th>
#       <td>@MoranT555 אבל זה בדיוק העניין. זה מנקודת מבטך...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1331</th>
#       <td>@DaphnaLiel את רצינית? איך את מצפה שמישו יקח א...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>4599</th>
#       <td>למה , למה , למה אלוהים ברא את הבדואים וגם העני...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>2729</th>
#       <td>@yakovahimeir פשוט וקל נתניהו שמאל קיצון ,ראה ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>3912</th>
#       <td>@Yossi_eli כי המפגינים בבלפור בתל אביב ובצמתים...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>4592</th>
#       <td>@DSociologist @JustAvishai פסדר זוט הנסיכה אני...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>419</th>
#       <td>לאיזה רמה אתם יורדים בושה</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>2715</th>
#       <td>בשעה שההורים וסבא וסבתא שלי מתחסנים ראש הממשלה...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>3357</th>
#       <td>איתמר בן גביר הפעם אתה בטוח נכנס ויש מצב שתגיע...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1000</th>
#       <td>כן זה ידוע המימד החמישיעוד מ. 48 הכל שלכם.</td>
#       <td>Positive</td>
#     </tr>
#   </tbody>
# </table>
# <p>1001 rows × 2 columns</p>
# </div>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/data/shuffledData.csv')
df['split'] = np.random.randn(df.shape[0], 1)

msk = np.random.rand(len(df)) <= 0.7

train = df[msk]
test = df[~msk]

msk2 = np.random.rand(len(test)) <= 0.2

test2=df[msk2]
val=df[~msk2]




data_table.DataTable(test2,include_index=False, num_rows_per_page=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-3e9537130787> in <module>()
#      10 test = df[~msk]
#      11
# ---> 12 msk2 = np.random.rand(test) <= 0.2
#      13
#      14 test2=df[msk2]
#
# mtrand.pyx in numpy.random.mtrand.RandomState.rand()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.random_sample()
#
# _common.pyx in numpy.random._common.double_fill()
#
# TypeError: 'DataFrame' object cannot be interpreted as an integer
