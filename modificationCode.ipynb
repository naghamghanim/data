# %% [markdown]
# <a href="https://colab.research.google.com/github/naghamghanim/data/blob/main/modificationCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/data
# !git clone https://github.com/naghamghanim/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 596, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 596 (delta 102), reused 94 (delta 31), pack-reused 431
# Receiving objects: 100% (596/596), 11.69 MiB | 23.70 MiB/s, done.
# Resolving deltas: 100% (356/356), done.

# %%
import sys
import argparse
sys.path.append('/content/data/')

# %%
# !mkdir /content/output/

# %%
#shufflying data

import pandas as pd
from google.colab import data_table

df = pd.read_csv('/content/data/models/M1/DatasetM1.csv',encoding='utf8')
df.sample(frac=1).reset_index(drop=True)

df = pd.DataFrame(df, columns = ['text', 'label'])
data_table.DataTable(df.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>@yarivop @amit_segal ימח שמך יא גוי!</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>השמאל בישראל הוא מרצ. על הגדר לצידם יושבים עוכ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>@EfratFinkel בעיקר 53 שנות כיבוש ושליטה על אוכ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>RT @HShvili: @GushNegedKibush נסיון ללינץ׳ ע״י...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>@MoranT555 מורן אני ציוני ואני ימני אפילו קיצו...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1995</th>
#       <td>יש גם יתרונות לגור ליד כפר ערבי/בדואי - הכל פת...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1996</th>
#       <td>@TheWireIL לדעתי הסצינה שהם חוקרים את הבית של ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1997</th>
#       <td>@bezalelsm נראה לי שהמקרה מזכיר לך את ימך היפי...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1998</th>
#       <td>@Elky_Bergstein "הקיבוצים שלכם" הפריחו כאן שממ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1999</th>
#       <td>@IlanShiloah אתה אויב הציבור מספר אחד ! אתה מס...</td>
#       <td>Negative</td>
#     </tr>
#   </tbody>
# </table>
# <p>2000 rows × 2 columns</p>
# </div>

# %%
df.to_csv("/content/data/models/M2/shuffledData.csv", sep=',', index=False,encoding='utf8')

# %%
#cleaning data from rows val dataset

import pandas as pd
import numpy as np
from google.colab import data_table
import re

#here read val file
df  = pd.read_csv('/content/data/models/shuffledOurData2000.csv',encoding='utf8') 


df['text'] = df['text'].replace('[0-9]', '', regex=True)
df['text']= df['text'].replace('_', '', regex=True)
df['text']= df['text'].replace('/', '', regex=True)
df['text'] = df['text'].replace('@', '', regex=True)
df['text'] = df['text'].replace(r'\s*[A-Za-z]+\b', '', regex=True)

df = pd.DataFrame(df, columns = ['text', 'label'])
df.to_csv('/content/data/models/shuffledOurData2000-cleaned.csv', index=False,encoding='utf8')


data_table.DataTable(df,include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>נראה לי שהמקרה מזכיר לך את ימך היפים בגבעות ש...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>נסראללה: יורש העצר הסעודי ביקש מטראמפ לרצוח או...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>: ערבי שתומך ביהודים זה ערבי מחמד? כי מה מצופה...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>תעמולת שווא סלובנית אנטישמית. השירות הציבורי ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>: תעמולת שווא סלובנית אנטישמית. השירות הציבורי...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1995</th>
#       <td>זה האמא של הפייר יצאתם לנו מכל החורים אם הפול...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1996</th>
#       <td>מפלגת טרור אנטישמית קיצונית המפלגה האנטישמית ה...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1997</th>
#       <td>אחרי ההחלטה הנכונה של אוחנה שלא לחסן אסירים בט...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1998</th>
#       <td>כןןן היה מצחיק רצח</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1999</th>
#       <td>לא, ברצינות. אתה רוצה שאשים פה את הציוצים שלי...</td>
#       <td>Positive</td>
#     </tr>
#   </tbody>
# </table>
# <p>2000 rows × 2 columns</p>
# </div>

# %%
#select random lines from csv file
import pandas as pd
import numpy as np
from google.colab import data_table

#1500 from here
#df1  = pd.read_csv('/content/data/models/shuffledOurData2000-cleaned.csv',encoding='utf8') 
#train, val, test = np.split(df1.sample(frac=1), [int(1*len(df1)),int(.75*len(df1))])

#here we took 1500 train data
#df1 = pd.DataFrame(train, columns = ['text', 'label'])

#df1.to_csv('/content/data/models/M6/OurData2000.csv', index=False,encoding='utf8')

#data_table.DataTable(train,include_index=False, num_rows_per_page=10)




#1000 from here
df2  = pd.read_csv('/content/data/models/TheirData2000.csv',encoding='utf8') 
df2=df2.dropna()

#train, val, test = np.split(df2.sample(frac=1), [int(.7*len(df2)),int(.75*len(df2))])
#df2 = pd.DataFrame(train, columns = ['text', 'label'])
df2.to_csv('/content/data/models/M7/TheirData2000.csv', index=False,encoding='utf8')


#data_table.DataTable(train,include_index=False, num_rows_per_page=10)

# %%
#merge 2 csv files

import pandas as pd
import numpy as np
from google.colab import data_table

df1  = pd.read_csv('/content/data/models/M6/OurData2000.csv',encoding='utf8') 

df1.to_csv('/content/data/models/M6/TheirData1500.csv', mode='a', index=False, header=False)

# %%
#check for duplicate
import pandas as pd
import numpy as np
from google.colab import data_table

df2  = pd.read_csv('/content/data/models/M7/train.csv',encoding='utf8') 

bool_series = df2.duplicated(keep='last')

print(bool_series)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2021    False
# 2022    False
# 2023    False
# 2024    False
# 2025    False
# Length: 2026, dtype: bool

# %%
import pandas as pd
import numpy as np
from google.colab import data_table
#here shuffle the final data
#df = pd.read_csv('/content/data/finalData.csv')
#df.sample(frac=1).reset_index(drop=True)

#data_table.DataTable(df.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)
#df.to_csv("/content/output/shuffledData.csv", sep='\t')


#splitting data into train, test and val datasets
iris = pd.read_csv('/content/data/models/M4/Dataset-test.csv') 

# one line split only into two datasets train and test without validation dataset
#train, validation, test = np.split(iris.sample(frac=1), [int(.7*len(iris)),int(.6*len(iris))])

# one line split only into two datasets train 70% and test 20% validation 10% dataset
train, val, test = np.split(iris.sample(frac=1), [int(.7*len(iris)),int(.75*len(iris))])

data_table.DataTable(iris,include_index=False, num_rows_per_page=10)


df = pd.DataFrame(train, columns = ['text', 'label'])
df.to_csv('/content/data/models/M4/train.csv', index=False)

df = pd.DataFrame(test, columns = ['text', 'label'])
df.to_csv('/content/data/models/M4/test.csv', index=False)

df = pd.DataFrame(val, columns = ['text', 'label'])
df.to_csv('/content/data/models/M4/val.csv', index=False)

# %%
# read number of rows from csv file and append into csv file

import itertools
import pandas as pd
import numpy as np
from google.colab import data_table

#read dataset from their paper
data = pd.read_csv('/content/data/models/Dataset.csv',nrows=2000)

data_table.DataTable(data,include_index=False, num_rows_per_page=10)

df = pd.DataFrame(data, columns = ['text', 'label'])
df.to_csv('/content/data/models/M3/2000rows.csv', index=False)

# %%
import pandas as pd
import numpy as np
from google.colab import data_table

#merge 2 csv files
data1=pd.read_csv('/content/data/models/M1/train.csv')
data2=pd.read_csv('/content/data/models/M3/2000rows.csv')

df1 = pd.DataFrame(data1, columns = ['text', 'label'])
df2 = pd.DataFrame(data1, columns = ['text', 'label'])
#out = df2.append(df1)

out=pd.merge(df1, df2)

df = pd.DataFrame(out, columns = ['text', 'label'])
#df.to_csv('/content/data/models/M3/train.csv', index=False)
data_table.DataTable(out,include_index=False, num_rows_per_page=10)


#with open('C:/JIRA Excel File/result.csv', 'w', encoding='utf-8') as f:
 #   out.to_csv(f, index=False)
