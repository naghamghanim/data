# %% [markdown]
# <a href="https://colab.research.google.com/github/naghamghanim/data/blob/main/modificationCode23_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/data
# !git clone https://github.com/naghamghanim/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 1054, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 1054 (delta 68), reused 82 (delta 29), pack-reused 927
# Receiving objects: 100% (1054/1054), 58.52 MiB | 16.06 MiB/s, done.
# Resolving deltas: 100% (632/632), done.
# Checking out files: 100% (239/239), done.

# %%
import sys
import argparse
sys.path.append('/content/data/')

# %%
# !mkdir /content/output/

# %%
# Select range of rows from csv file
import pandas as pd
import itertools
from google.colab import data_table


df = pd.read_csv('/content/data/OurData.csv',encoding='utf8')

df1 = pd.DataFrame(df, columns = [ 'TweetText','NOT'])
data_table.DataTable(df1.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)

#here select only not hate from our data
df2=df1.loc[df1['NOT'] == "NOT"]
#data_table.DataTable(df2.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)



#save not hate records
#df2.to_csv("/content/data/NotHate.csv", sep=',', index=False,encoding='utf8')

df3 = pd.read_csv('/content/data/NotHate.csv',encoding='utf8')

n = 1255
df4=df3.iloc[1:n]

data_table.DataTable(df4.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)

df4['NOT'] = "Positive"

df4.rename(columns = {'TweetText':'text'}, inplace = True)
df4.rename(columns = {'NOT':'label'}, inplace = True)


data_table.DataTable(df4.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)

df4.to_csv("/content/data/without_cleaning/ours2000-original.csv", sep=',', index=False,encoding='utf8')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#select hate records

df1 = pd.DataFrame(df, columns = ['TweetText', 'NOT'])
data_table.DataTable(df1.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)
op = df1.loc[(df1['NOT'] != "NOT") & (df1['NOT'] != "") & (df1['NOT'] != "Violence") &  (df1['NOT'] != "violence")]
op2 = op[op.NOT.notnull()]

op2['NOT'] = "Negative"

op2.rename(columns = {'TweetText':'text'}, inplace = True)
op2.rename(columns = {'NOT':'label'}, inplace = True)

data_table.DataTable(op2.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)

op2.to_csv("/content/data/without_cleaning/Hate.csv", sep=',', index=False,encoding='utf8')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# merge ours 2000

import pandas as pd
import numpy as np
from google.colab import data_table

df1  = pd.read_csv('/content/data/without_cleaning/Hate.csv',encoding='utf8') 

#here added to this file
df1.to_csv('/content/data/without_cleaning/ours2000-original.csv', mode='a', index=False, header=False,encoding='utf8')
data_table.DataTable(df1.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>@antoineeliaroni @TamarAlfi @AyOdeh עדיף גם לא...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>@gidonsaar @AyalaHasson גדעון הבהמה🐷יש לך ילדה...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>@DovMorell @ROCOwas2short מי זה הם כולם? גנץ מ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>שוטר מסביר לי מדוע הוא חושש שאסתובב בהפגנה, הו...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>@naomilster @uribreitman הרש״פ מונעת טרור מתוך...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>751</th>
#       <td>נתניהו רואה בסקרים שאין לו רוב יהודי לכן הוא ה...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>752</th>
#       <td>@KalmanLiebskind משטרת מחז שי זה משטרה של חלאו...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>753</th>
#       <td>@Avihay_Hajama @Eliezer_yehoda פלסטיני מיידה א...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>754</th>
#       <td>@a51LetvgkZzmWCw צפיתי. מדהים. ימות המשיח. הער...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>755</th>
#       <td>@limor_moyal אני בתור אזרח ערבי, הייתי רושם לע...</td>
#       <td>Negative</td>
#     </tr>
#   </tbody>
# </table>
# <p>756 rows × 2 columns</p>
# </div>

# %%
##shufflying data

import pandas as pd
from google.colab import data_table

df = pd.read_csv('/content/data/without_cleaning/ours2000-original.csv',encoding='utf8')
df2=df.sample(frac=1).reset_index(drop=True)

df = pd.DataFrame(df, columns = ['text', 'label'])
data_table.DataTable(df.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>@ShaiCohen13 שי, אתה יודע שאירוע הכי קטן מול ע...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>@Haim_rv @AyOdeh איימן עודה אויב אבל לשתף פעול...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>נסראללה נשאל בראיון על היחס שלהם לערביי ישראל ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>@netanyahu סבא שלך מוסלמי? לאישתך הפלסטינאית ש...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>RT @ISudri: @judash0 פרצופו האמיתי של אבי ביטו...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2005</th>
#       <td>כשאנחנו נהנים בבית מסרטים טובים אוכל טוב וזמן ...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>2006</th>
#       <td>אז מתי לאולפן שישי מצרפים שופר ערבי? לשם האיזו...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>2007</th>
#       <td>@NitzanHorowitz באמת, כמה "יפה", מצד הכהניסט ה...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>2008</th>
#       <td>אילו היה הנער היהודי,אהוביה סנדק ז"ל,ערבי שנהר...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>2009</th>
#       <td>@AlmogTea @shivatsion @SuleimanMas1 @BarakRavi...</td>
#       <td>Negative</td>
#     </tr>
#   </tbody>
# </table>
# <p>2010 rows × 2 columns</p>
# </div>

# %%
df2.to_csv("/content/data/without_cleaning/ours2000-shuffled.csv", sep=',', index=False,encoding='utf8')

# %%
#Cleaning only usernames from dataset

import pandas as pd
import numpy as np
from google.colab import data_table
import re

#here read val file
df  = pd.read_csv('/content/data/without_cleaning/ours2000-shuffled.csv',encoding='utf8') 


def clean_text(row, options):

    if options['lowercase']:
        row = row.lower()


    if options['remove_url']:
        row = row.replace('http\S+|www.\S+', '')

    if options['remove_mentions']:
       # row = row.replace('@[A-Za-z0-9]+', '')
       #df['text'] = df['text'].replace('@[A-Za-z0-9]+', '', regex=True)
       re.sub("@[A-Za-z0-9]+","", "@thisisauser text")
       ' text'

    return row

clean_config = {
    'remove_url': False,
    'remove_mentions': True,
    'decode_utf8': True,
    'lowercase': False
    }

#df['text'] = df['text'].apply(clean_text, args=(clean_config,))


df['text'] = df['text'].str.replace(r'\s*@\w+', '', regex=True)
df['text'] = df['text'].str.replace(r'\s*\B@\w+', '', regex=True)
df['text'] = df['text'].str.replace(r'\s*@\S+', '', regex=True)
df['text'] = df['text'].str.replace(r'\s*@\S+\b', '', regex=True)

data_table.DataTable(df.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)
df.to_csv("/content/data/without_cleaning/ours2000-cleaned.csv", sep=',', index=False,encoding='utf8')

# %%
#cleaning data from rows val dataset

import pandas as pd
import numpy as np
from google.colab import data_table
import re

#here read val file
df  = pd.read_csv('/content/data/without_cleaning/ours2000.csv',encoding='utf8') 


df['text'] = df['text'].replace('[0-9]', '', regex=True)
df['text']= df['text'].replace('_', '', regex=True)
df['text']= df['text'].replace('/', '', regex=True)
df['text'] = df['text'].replace('@', '', regex=True)
df['text'] = df['text'].replace(r'\s*[A-Za-z]+\b', '', regex=True)

df = pd.DataFrame(df, columns = ['text', 'label'])
df.to_csv('/content/data/models4/ours2000-cleaned.csv', index=False,encoding='utf8')


data_table.DataTable(df,include_index=False, num_rows_per_page=10)

# %%
#select random lines from csv file
import pandas as pd
import numpy as np
from google.colab import data_table


df1  = pd.read_csv('/content/data/without_cleaning/ours2000-cleaned.csv',encoding='utf8') 

#split into 3 datasets
train, val, test = np.split(df1.sample(frac=1), [int(0.7*len(df1)),int(.75*len(df1))])


# select only 1000
#train, val, test = np.split(df1.sample(frac=1), [int(0.7*len(df1)),int(.75*len(df1))])


#here we took 1500 train data
#df1 = pd.DataFrame(val, columns = ['text', 'label'])
#data_table.DataTable(val,include_index=False, num_rows_per_page=10)

#df1.to_csv('/content/data/models2/M2/their1000.csv', index=False,encoding='utf8')



#1000 from here
#df2  = pd.read_csv('/content/data/models/TheirData2000.csv',encoding='utf8') 
#df2=df2.dropna()

#train, val, test = np.split(df2.sample(frac=1), [int(.7*len(df2)),int(.75*len(df2))])
#df2 = pd.DataFrame(train, columns = ['text', 'label'])
#df2.to_csv('/content/data/models/M7/TheirData2000.csv', index=False,encoding='utf8')


data_table.DataTable(val,include_index=False, num_rows_per_page=10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1597</th>
#       <td>מי אלה בבונים?? מי אלה אוכלי חינם?? מי אלה עוכ...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>702</th>
#       <td>אני ממש מקווה שאני אומר את המובן מאליו, שאף אז...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>775</th>
#       <td>בניגוד למה שהשמאלנים חושבים על עצמם, השמאל מי...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1579</th>
#       <td>מחבל מתאבד הומו בגן עדן: https://t.co/ZpD56QmiVY</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>178</th>
#       <td>לו החברה הערבית לא היית שואפת לשחוט יהודים זה...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1120</th>
#       <td>זה שיח של אשכנזים מנותקים שלא קראו בחייהם מיל...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>716</th>
#       <td>מישהו עיצבן אותי הוא כתב ככה תגובה על מה שהגיד...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>934</th>
#       <td>אני לא מכירה מספיק שמות, אבל חייבים נציג ערבי...</td>
#       <td>Positive</td>
#     </tr>
#     <tr>
#       <th>1533</th>
#       <td>תחליף לריבונות? תחליף תקליט אולי? (לגבי עזה: ל...</td>
#       <td>Negative</td>
#     </tr>
#     <tr>
#       <th>1298</th>
#       <td>5 עבריינים נוסעים בשטחים לעשות פיגוע אחד העבר...</td>
#       <td>Negative</td>
#     </tr>
#   </tbody>
# </table>
# <p>100 rows × 2 columns</p>
# </div>

# %%
df1 = pd.DataFrame(train, columns = ['text', 'label'])
df1.to_csv('/content/data/without_cleaning/M1/train.csv', index=False,encoding='utf8')

df1 = pd.DataFrame(test, columns = ['text', 'label'])
df1.to_csv('/content/data/without_cleaning/M1/test.csv', index=False,encoding='utf8')

df1 = pd.DataFrame(val, columns = ['text', 'label'])
df1.to_csv('/content/data/without_cleaning/M1/val.csv', index=False,encoding='utf8')

# %%
#counting number of positive and negative


import pandas as pd
from google.colab import data_table

df  = pd.read_csv('/content/data/without_cleaning/M1/val.csv',encoding='utf8') 
df = pd.DataFrame(df, columns = ['label'])
data_table.DataTable(df,include_index=False, num_rows_per_page=10)

df['label'].value_counts()
# Out:
# Positive    65
# Negative    35
# Name: label, dtype: int64

# %%
#merge 2 csv files

import pandas as pd
import numpy as np
from google.colab import data_table

df1  = pd.read_csv('/content/data/models4/their2000.csv',encoding='utf8') 

#here added to this file
df1.to_csv('/content/data/models4/M3/train.csv', mode='a', index=False, header=False)

# %%
#counitng number of occurences in specific column
import pandas as pd
from google.colab import data_table

df  = pd.read_csv('/content/data/OurData.csv',encoding='utf8') 
df = pd.DataFrame(df, columns = ['target'])
data_table.DataTable(df,include_index=False, num_rows_per_page=10)

df['target'].value_counts()[:6].index.tolist()
# Out:
# ['UNT', 'arabs', 'palestinians', 'not clear', 'bibi netnyahu', 'Jews']

# %%
# find the longest sentence in TweetText

df  = pd.read_csv('/content/data/OurData.csv',encoding='utf8') 
df = pd.DataFrame(df, columns = ['TweetText'])
data_table.DataTable(df,include_index=False, num_rows_per_page=10)


df['TweetText'].str.len().max()
# Out:
# 913.0

# %%
#check for duplicate
import pandas as pd
import numpy as np
from google.colab import data_table

df2  = pd.read_csv('/content/data/models/M7/train.csv',encoding='utf8') 

bool_series = df2.duplicated(keep='last')

print(bool_series)

# %%
import pandas as pd
import numpy as np
from google.colab import data_table
#here shuffle the final data
#df = pd.read_csv('/content/data/finalData.csv')
#df.sample(frac=1).reset_index(drop=True)

#data_table.DataTable(df.sample(frac=1).reset_index(drop=True),include_index=False, num_rows_per_page=10)
#df.to_csv("/content/output/shuffledData.csv", sep='\t')


#splitting data into train, test and val datasets
iris = pd.read_csv('/content/data/models/M4/Dataset-test.csv') 

# one line split only into two datasets train and test without validation dataset
#train, validation, test = np.split(iris.sample(frac=1), [int(.7*len(iris)),int(.6*len(iris))])

# one line split only into two datasets train 70% and test 20% validation 10% dataset
train, val, test = np.split(iris.sample(frac=1), [int(.7*len(iris)),int(.75*len(iris))])

data_table.DataTable(iris,include_index=False, num_rows_per_page=10)


df = pd.DataFrame(train, columns = ['text', 'label'])
df.to_csv('/content/data/models/M4/train.csv', index=False)

df = pd.DataFrame(test, columns = ['text', 'label'])
df.to_csv('/content/data/models/M4/test.csv', index=False)

df = pd.DataFrame(val, columns = ['text', 'label'])
df.to_csv('/content/data/models/M4/val.csv', index=False)

# %%
# read number of rows from csv file and append into csv file

import itertools
import pandas as pd
import numpy as np
from google.colab import data_table

#read dataset from their paper
data = pd.read_csv('/content/data/models/Dataset.csv',nrows=2000)

data_table.DataTable(data,include_index=False, num_rows_per_page=10)

df = pd.DataFrame(data, columns = ['text', 'label'])
df.to_csv('/content/data/models/M3/2000rows.csv', index=False)

# %%
import pandas as pd
import numpy as np
from google.colab import data_table

#merge 2 csv files
data1=pd.read_csv('/content/data/models/M1/train.csv')
data2=pd.read_csv('/content/data/models/M3/2000rows.csv')

df1 = pd.DataFrame(data1, columns = ['text', 'label'])
df2 = pd.DataFrame(data1, columns = ['text', 'label'])
#out = df2.append(df1)

out=pd.merge(df1, df2)

df = pd.DataFrame(out, columns = ['text', 'label'])
#df.to_csv('/content/data/models/M3/train.csv', index=False)
data_table.DataTable(out,include_index=False, num_rows_per_page=10)


#with open('C:/JIRA Excel File/result.csv', 'w', encoding='utf-8') as f:
 #   out.to_csv(f, index=False)
